# %%
import os
import json

# %%
files=os.listdir("❔・faq/")
base="❔・faq/"

# %%
for file in files:
    s=""
    a=file.split('_')
    content = json.loads(open(base+file).read())['messages']
    for i in range(len(content)):
        content=json.loads(open(base+file).read())['messages'][i][0]['content']
        content=content+"\n"
        s=s+content
    if '2021' in file:
        with open("files/faq/❔・faq_2021_"+a[1]+".txt", "a", encoding='utf8') as f:
            f.write(s+"\n\n///////////////////////////////////////////////////////////////////////////////////////////////\n\n")
    elif '2022' in file:
        with open("files/faq/❔・faq_2022_"+a[1]+".txt", "a", encoding='utf8') as f:
            f.write(s+"\n\n///////////////////////////////////////////////////////////////////////////////////////////////\n\n")
